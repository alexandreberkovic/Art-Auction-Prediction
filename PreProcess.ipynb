# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import xlrd
warnings.filterwarnings('ignore')

# %% [markdown]
# # Further Pre Processing - Standardize Currency - Medium - Country

# %%
#import clean data
df = pd.read_csv('cleaned_data.csv')
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Binhong Huang   05/30/2017     Christies        Hong Kong        1364
# 1  Binhong Huang   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Binhong Huang   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... height  \
# 0    paper     NaN  1947-01-01 00:00:00      USD    0.0  ...  33.66
# 1    paper     NaN  1990-01-01 00:00:00      USD    0.0  ...  13.58
# 2    paper     NaN                  NaN      USD    0.0  ...    NaN
# 3    paper     NaN                  NaN      USD    0.0  ...  40.94
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...  39.53
#
#   high_estimate  inscribed  low_estimate                      medium  \
# 0       64150.0        1.0       38490.0  watercolor and ink / paper
# 1       64150.0        1.0       38490.0  watercolor and ink / paper
# 2       23090.0        1.0       15400.0  watercolor and ink / paper
# 3      449050.0        1.0      320750.0  watercolor and ink / paper
# 4       12830.0        1.0       10260.0  watercolor and ink / paper
#
#    sales_price signed stamped                                        title  \
# 0      45900.0    1.0     0.0                              Misty Landscape
# 1          NaN    1.0     0.0                Conversations in the Mountain
# 2      22950.0    1.0     0.0  Peony and Insects / Peony and Butterfly (2)
# 3     433330.0    1.0     0.0                     Retreat in the Mountains
# 4      12240.0    1.0     0.0                       Villagers in the Woods
#
#    width
# 0  16.93
# 1  10.43
# 2    NaN
# 3  15.55
# 4  18.82
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Standardize Currency

# %%
#how many unique currencies are there?
df['currency'].nunique()
# Out:
# 28

# %%
#What are the most common
df['currency'].value_counts().head(10)
# Out:
# USD    28958
# GBP    14062
# EUR     4560
# HKD     3045
# CHF      322
# SEK      199
# CNY      167
# AUD      139
# CAD      119
# NOK       64
# Name: currency, dtype: int64

# %%
# Are there any rows with null currency values?
df[df['currency'].isnull()]
# Out:
#                    artist auction_date                  auction_house  \
# 12279     Adolph Gottlieb   05/13/2008                     Christies
# 12295     Adolph Gottlieb   05/14/2008                     Christies
# 12324     Adolph Gottlieb   05/22/2007        Bonhams & Butterfields
# 12341      Adriaen Coorte   03/28/2014  Hampel Fine Art Auctioneers
# 12354     Adriana Varejão   09/22/2011                 Bolsa De Arte
# ...                   ...          ...                            ...
# 53835  Zhu (ju Ming) Ming   05/25/2008                     Christies
# 53838  Zhu (ju Ming) Ming   05/25/2008                     Christies
# 53842  Zhu (ju Ming) Ming   05/25/2008                     Christies
# 53847  Zhu (ju Ming) Ming   05/25/2008                     Christies
# 53849  Zhu (ju Ming) Ming   05/25/2008                     Christies
#
#                                       auction_location auction_lot category  \
# 12279   The United States: New York Rockefeller Center          22      NaN
# 12295   The United States: New York Rockefeller Center         146      NaN
# 12324      The United States: California San Francisco          60      NaN
# 12341                                  Germany: Munich        1097      NaN
# 12354                           Brasil: Rio de Janeiro          44      NaN
# ...                                                ...         ...      ...
# 53835                                 China: Hong Kong         311      NaN
# 53838                                 China: Hong Kong         278      NaN
# 53842                                 China: Hong Kong         313      NaN
# 53847                                 China: Hong Kong         281      NaN
# 53849                                 China: Hong Kong         279      NaN
#
#                         country              created currency  dated  ...  \
# 12279  United States of America                  NaN      NaN    0.0  ...
# 12295  United States of America  1946-01-01 00:00:00      NaN    1.0  ...
# 12324  United States of America  1949-01-01 00:00:00      NaN    1.0  ...
# 12341                       NaN                  NaN      NaN    0.0  ...
# 12354                    Brazil  2001-01-01 00:00:00      NaN    1.0  ...
# ...                         ...                  ...      ...    ...  ...
# 53835                    Taiwan  1994-01-01 00:00:00      NaN    1.0  ...
# 53838                    Taiwan  1991-01-01 00:00:00      NaN    1.0  ...
# 53842                    Taiwan  1991-01-01 00:00:00      NaN    1.0  ...
# 53847                    Taiwan  1995-01-01 00:00:00      NaN    1.0  ...
# 53849                    Taiwan                  NaN      NaN    0.0  ...
#
#       height high_estimate  inscribed  low_estimate  \
# 12279  90.00           NaN        0.0           NaN
# 12295  25.47           NaN        0.0           NaN
# 12324  25.51           NaN        0.0           NaN
# 12341   5.63           NaN        0.0           NaN
# 12354  39.37           NaN        0.0           NaN
# ...      ...           ...        ...           ...
# 53835  24.02           NaN        0.0           NaN
# 53838  11.02           NaN        0.0           NaN
# 53842  12.60           NaN        1.0           NaN
# 53847  27.56           NaN        0.0           NaN
# 53849  55.00           NaN        0.0           NaN
#
#                                          medium  sales_price signed stamped  \
# 12279                             Oil on canvas      6537000    1.0     0.0
# 12295  Gouache watercolor and graphite on paper       145000    1.0     0.0
# 12324                          Gouache on paper        70000    1.0     0.0
# 12341                              Oil on paper       145000    1.0     0.0
# 12354                             Oil on canvas      1011236    1.0     0.0
# ...                                         ...          ...    ...     ...
# 53835                          Bronze sculpture       907500    1.0     0.0
# 53838                            Wood sculpture      1327500    1.0     0.0
# 53842                                Sculpture       1927500    1.0     0.0
# 53847                            Sculpture wood      3007500    1.0     0.0
# 53849                            Wood sculpture      4207500    0.0     0.0
#
#                                              title  width
# 12279                                   Cool Blast  70.00
# 12295                                  Mood Indigo  19.49
# 12324                                     Untitled  19.25
# 12341  STILL LIFE WITH SEA SHELLS ON A STONE PLATE   8.07
# 12354                                Macau Wall #5  39.37
# ...                                            ...    ...
# 53835                     Taiji Series - Push Hand  12.99
# 53838                   Taiji Series - Single Whip  15.75
# 53842                   Taiji Series - Single Whip  23.62
# 53847                   Taiji Series - Single Whip  27.56
# 53849                   Taiji Series - Single Whip  25.98
#
# [2075 rows x 22 columns]

# %%
# First, let's see what the most common auction locations are for rows with null currency values
df[df['currency'].isnull()].auction_location.value_counts().head(10)
# Out:
#  Bern                                              363
#  The United States: New York Rockefeller Center    338
#  United Kingdom: London New Bond Street            219
#  Germany: Munich                                   208
#  China: Hong Kong                                  134
#  France: Paris                                      69
#  Germany: Hamburg                                   57
#  Germany: Cologne                                   50
#  United Kingdom: London King Street                 50
#  Hong Kong                                          44
# Name: auction_location, dtype: int64

# %%
# Lets create a temporary column with the auction location country
df['auction_location_country'] = df['auction_location'].str.split(':').str[0]
#Clean any spaces
df['auction_location_country'] = df['auction_location_country'].str.strip()

# See how it looks
df[df['currency'].isnull()].auction_location_country.value_counts().head(10)
# Out:
# The United States           500
# Germany                     364
# Bern                        363
# United Kingdom              321
# China                       135
# France                       88
# United States of America     50
# Hong Kong                    46
# Ireland                      35
# Italy                        25
# Name: auction_location_country, dtype: int64

# %%
# See how this package works
import pycountry

country = pycountry.countries.get(name='Norway')
currency = pycountry.currencies.get(numeric=country.numeric)

currency.alpha_3
# Out:
# 'NOK'

# %%
# Iterate through all the rows with null currency
for index, row in df[df['currency'].isnull()].iterrows():
    # Get the country name from the auction_location column
    auction_location_country = row['auction_location_country']

    # Try getting the country object from the pycountry package, if error, skip
    try:
        country = pycountry.countries.get(name=auction_location_country)
        # Get the currency object from the pycountry package
        currency = pycountry.currencies.get(numeric=country.numeric)
        # Set the currency column to the alpha_3 code of the currency object
        df.loc[index, 'currency'] = currency.alpha_3
    except:
        pass

# Check that we have no more null currency values
df[df['currency'].isnull()]
# Out:
#                    artist auction_date                  auction_house  \
# 12279     Adolph Gottlieb   05/13/2008                     Christies
# 12295     Adolph Gottlieb   05/14/2008                     Christies
# 12324     Adolph Gottlieb   05/22/2007        Bonhams & Butterfields
# 12341      Adriaen Coorte   03/28/2014  Hampel Fine Art Auctioneers
# 12354     Adriana Varejão   09/22/2011                 Bolsa De Arte
# ...                   ...          ...                            ...
# 52845        Zhang Daqian   12/11/2010                      Lempertz
# 53332      Zhang Xiaogang   11/20/2006        Bonhams & Butterfields
# 53339      Zhang Xiaogang   11/20/2006        Bonhams & Butterfields
# 53410      Zhang Xiaogang   05/14/2008                     Christies
# 53646  Zhu (ju Ming) Ming   11/20/2006        Bonhams & Butterfields
#
#                                       auction_location auction_lot category  \
# 12279   The United States: New York Rockefeller Center          22      NaN
# 12295   The United States: New York Rockefeller Center         146      NaN
# 12324      The United States: California San Francisco          60      NaN
# 12341                                  Germany: Munich        1097      NaN
# 12354                           Brasil: Rio de Janeiro          44      NaN
# ...                                                ...         ...      ...
# 52845                                 Germany: Cologne          72      NaN
# 53332      The United States: California San Francisco        6148      NaN
# 53339      The United States: California San Francisco        6147      NaN
# 53410   The United States: New York Rockefeller Center         329      NaN
# 53646      The United States: California San Francisco        6163      NaN
#
#                         country              created currency  dated  ...  \
# 12279  United States of America                  NaN      NaN    0.0  ...
# 12295  United States of America  1946-01-01 00:00:00      NaN    1.0  ...
# 12324  United States of America  1949-01-01 00:00:00      NaN    1.0  ...
# 12341                       NaN                  NaN      NaN    0.0  ...
# 12354                    Brazil  2001-01-01 00:00:00      NaN    1.0  ...
# ...                         ...                  ...      ...    ...  ...
# 52845                     China  1944-01-01 00:00:00      NaN    1.0  ...
# 53332                     China  2005-01-01 00:00:00      NaN    1.0  ...
# 53339                     China  2001-01-01 00:00:00      NaN    1.0  ...
# 53410                     China  2000-01-01 00:00:00      NaN    1.0  ...
# 53646                    Taiwan  1990-01-01 00:00:00      NaN    1.0  ...
#
#       high_estimate inscribed  low_estimate  \
# 12279           NaN       0.0           NaN
# 12295           NaN       0.0           NaN
# 12324           NaN       0.0           NaN
# 12341           NaN       0.0           NaN
# 12354           NaN       0.0           NaN
# ...             ...       ...           ...
# 52845           NaN       0.0           NaN
# 53332           NaN       0.0           NaN
# 53339           NaN       0.0           NaN
# 53410           NaN       0.0           NaN
# 53646           NaN       0.0           NaN
#
#                                          medium  sales_price  signed stamped  \
# 12279                             Oil on canvas      6537000     1.0     0.0
# 12295  Gouache watercolor and graphite on paper       145000     1.0     0.0
# 12324                          Gouache on paper        70000     1.0     0.0
# 12341                              Oil on paper       145000     1.0     0.0
# 12354                             Oil on canvas      1011236     1.0     0.0
# ...                                         ...          ...     ...     ...
# 52845                              Ink on paper       204000     1.0     0.0
# 53332                             Oil on canvas       180000     1.0     0.0
# 53339                             Oil on canvas       150000     1.0     0.0
# 53410                             Oil on canvas       993000     1.0     0.0
# 53646                            Wood sculpture       115000     1.0     0.0
#
#                                                    title  width  \
# 12279                                         Cool Blast  70.00
# 12295                                        Mood Indigo  19.49
# 12324                                           Untitled  19.25
# 12341        STILL LIFE WITH SEA SHELLS ON A STONE PLATE   8.07
# 12354                                      Macau Wall #5  39.37
# ...                                                  ...    ...
# 52845  Drei Gelehrte beim Brettspiel an einem bizarre...  21.77
# 53332                                 Amnesia and Memory  20.00
# 53339                                        Baby No. 19  15.75
# 53410                    Bloodline Series (Two Comrades)  39.25
# 53646                          Buffalo dragging the wood  15.75
#
#        auction_location_country
# 12279         The United States
# 12295         The United States
# 12324         The United States
# 12341                   Germany
# 12354                    Brasil
# ...                         ...
# 52845                   Germany
# 53332         The United States
# 53339         The United States
# 53410         The United States
# 53646         The United States
#
# [1491 rows x 23 columns]

# %%
# That didn't help much, only 500 rows were recovred, let's just create a manual dictionary for the rest
currency_dict = {
    'The United States': 'USD',
    'Germany': 'EUR',
    'Bern': 'CHF',
    'France': 'EUR',
    'United States of America': 'USD',
    'Ireland': 'EUR',
    'Italy': 'EUR',
    'Czech Republic': 'EUR',
    'Belgium': 'EUR',
    'Italia': 'EUR',
    'Brasil': 'BRL',
    'Spain': 'EUR',
    'Finland': 'EUR',
    'Lefèvre': 'EUR',
    'Austria': 'EUR',
    'Netherlands': 'EUR',
    'The Netherlands': 'EUR',
}

# Iterate through all the rows with null currency
for index, row in df[df['currency'].isnull()].iterrows():
    # Get the country name from the auction_location column
    auction_location_country = row['auction_location_country']

    # If the country is in the dictionary, set the currency column to the value
    if auction_location_country in currency_dict:
        df.loc[index, 'currency'] = currency_dict[auction_location_country]

# Check that we have no more null currency values
df[df['currency'].isnull()]
# Out:
#                                 artist auction_date  \
# 17721                   Bernard Buffet   12/06/2006
# 17948                   Brett Whiteley   07/31/2006
# 17998                   Brett Whiteley   11/27/2013
# 30335  Ivan Konstantinovich Aivazovsky   04/13/2005
# 31158             Jean Baptiste Greuze   11/17/2004
# 34522                 Jusepe De Ribera   12/04/2008
# 35462    Konstantin Egorovich Makovsky   05/19/2005
# 36600                  Lucas Cranach I   09/04/2008
# 37412         Lyonel Charles Feininger   05/06/2005
# 38097                     Marc Chagall   12/14/2012
# 48435               Samuel John Peploe   12/06/2008
# 50326                     Wang Guangyi   12/06/2009
#
#                            auction_house      auction_location auction_lot  \
# 17721                             Poette                Castor          76
# 17948                             Lawson              Menzies          343
# 17998                          Deutscher              Menzies           19
# 30335                            Chochon      Barré & Allardi           36
# 31158                           Delorme      Collin du Bocage           78
# 34522                               Kahn            Dumousset          210
# 35462  Gelos Antiques and Auction House         Russia: Moscow          35
# 36600                       Auktionshaus              Weidler          410
# 37412                Peter Kiefer • Buch   und Kunstauktionen         4962
# 38097          Hôtel des Ventes de Monte                Carlo           36
# 48435                Shapes Auctioneers    Scotland: Edinburgh         797
# 50326                 Ravenel Art Group         Taiwan: Taipei         157
#
#       category                   country              created currency  dated  \
# 17721      NaN                    France                  NaN      NaN    0.0
# 17948      NaN                 Australia  1964-01-01 00:00:00      NaN    1.0
# 17998      NaN                 Australia  1973-01-01 00:00:00      NaN    1.0
# 30335      NaN                    Russia                  NaN      NaN    0.0
# 31158      NaN                    France  1759-01-01 00:00:00      NaN    1.0
# 34522      NaN                     Spain                  NaN      NaN    0.0
# 35462      NaN                    Russia                  NaN      NaN    0.0
# 36600      NaN                   Germany                  NaN      NaN    0.0
# 37412      NaN  United States of America  1946-01-01 00:00:00      NaN    1.0
# 38097      NaN                    France                  NaN      NaN    0.0
# 48435      NaN                  Scotland                  NaN      NaN    0.0
# 50326      NaN                     China  2002-01-01 00:00:00      NaN    1.0
#
#        ... high_estimate inscribed  low_estimate  \
# 17721  ...           NaN       0.0           NaN
# 17948  ...           NaN       0.0           NaN
# 17998  ...           NaN       0.0           NaN
# 30335  ...           NaN       0.0           NaN
# 31158  ...           NaN       1.0           NaN
# 34522  ...           NaN       0.0           NaN
# 35462  ...           NaN       0.0           NaN
# 36600  ...           NaN       0.0           NaN
# 37412  ...           NaN       0.0           NaN
# 38097  ...           NaN       0.0           NaN
# 48435  ...           NaN       0.0           NaN
# 50326  ...           NaN       0.0           NaN
#
#                                 medium  sales_price  signed stamped  \
# 17721                    Oil on canvas       145000     1.0     0.0
# 17948                        Painting        204000     0.0     0.0
# 17998                   Oil on plywood       228000     1.0     0.0
# 30335  Oil on canvas mounted on carton        80000     0.0     0.0
# 31158                    Oil on canvas        80000     1.0     0.0
# 34522    Pen brown washed, on handmade       105000     0.0     0.0
# 35462                    Oil on canvas       700000     0.0     0.0
# 36600                         Tempera        112000     0.0     0.0
# 37412                    Oil on canvas       150000     1.0     0.0
# 38097                             Ink        270000     0.0     0.0
# 48435                     Oil on panel        70000     1.0     0.0
# 50326                    Oil on canvas       156716     1.0     0.0
#
#                                                    title  width  \
# 17721                                    New York-Subway  39.37
# 17948                        Cheetah in Rillington Place  72.05
# 17998                        TO REPEAT WITHOUT REPEATING  34.65
# 30335                                    Temple en Grèce  10.24
# 31158  Portrait de César Gabriel, Duc de Choiseul Pra...  28.54
# 34522                                   Die letzte Fahrt   6.69
# 35462                            The Ceremony of Kissing  84.45
# 36600                     Apoll und Diana in  Landschaft  20.08
# 37412              Yacht race - "Racing Skerry Cruisers"  25.00
# 38097                    L&#146;écuyère au double profil  19.69
# 48435                                     Ile de Bréhart  16.14
# 50326                 Great Criticism Series - Channel V  59.06
#
#        auction_location_country
# 17721                    Castor
# 17948                   Menzies
# 17998                   Menzies
# 30335           Barré & Allardi
# 31158          Collin du Bocage
# 34522                 Dumousset
# 35462                    Russia
# 36600                   Weidler
# 37412        und Kunstauktionen
# 38097                     Carlo
# 48435                  Scotland
# 50326                    Taiwan
#
# [12 rows x 23 columns]

# %%
# Okay, we went down to 12 rows with null currency values, let's just drop them
df = df.dropna(subset=['currency'])

#Drop the temporary column
df = df.drop('auction_location_country', axis=1)

# Check that we have no more null currency values
df[df['currency'].isnull()]
# Out:
# Empty DataFrame
# Columns: [artist, auction_date, auction_house, auction_location, auction_lot, category, country, created, currency, dated, edition, foundry, height, high_estimate, inscribed, low_estimate, medium, sales_price, signed, stamped, title, width]
# Index: []
#
# [0 rows x 22 columns]

# %%
#Try out converter package
from currency_converter import CurrencyConverter
c = CurrencyConverter(fallback_on_missing_rate=True, fallback_on_wrong_date=True)
c.convert(100, 'EUR', 'USD')
# Out:
# 97.06

# %%
#Will have to convert based on the date of the auction
from datetime import date
c.convert(100, 'EUR', 'USD', date=date(2000, 1, 28))
# Out:
# 98.48

# %%
# Clean the cells
df['sales_price'] = df['sales_price'].str.replace('[a-zA-Z]', '')
df['sales_price'] = df['sales_price'].str.replace(',', '')
df['sales_price'] = df['sales_price'].str.replace('$', '')
df['sales_price'] = df['sales_price'].str.replace(' ', '')
df['sales_price'] = df['sales_price'].str.replace('[', '')
df['sales_price'] = df['sales_price'].str.replace(']', '')

# If the cell is empty, fill it with 0
df['sales_price'] = df['sales_price'].fillna(0)
df['sales_price'] = df['sales_price'].replace('', 0)

# Convert to float
df['sales_price'] = df['sales_price'].astype(float)

# %%
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Binhong Huang   05/30/2017     Christies        Hong Kong        1364
# 1  Binhong Huang   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Binhong Huang   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... height  \
# 0    paper     NaN  1947-01-01 00:00:00      USD    0.0  ...  33.66
# 1    paper     NaN  1990-01-01 00:00:00      USD    0.0  ...  13.58
# 2    paper     NaN                  NaN      USD    0.0  ...    NaN
# 3    paper     NaN                  NaN      USD    0.0  ...  40.94
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...  39.53
#
#   high_estimate  inscribed  low_estimate                      medium  \
# 0       64150.0        1.0       38490.0  watercolor and ink / paper
# 1       64150.0        1.0       38490.0  watercolor and ink / paper
# 2       23090.0        1.0       15400.0  watercolor and ink / paper
# 3      449050.0        1.0      320750.0  watercolor and ink / paper
# 4       12830.0        1.0       10260.0  watercolor and ink / paper
#
#    sales_price signed  stamped                                        title  \
# 0      45900.0    1.0      0.0                              Misty Landscape
# 1          0.0    1.0      0.0                Conversations in the Mountain
# 2      22950.0    1.0      0.0  Peony and Insects / Peony and Butterfly (2)
# 3     433330.0    1.0      0.0                     Retreat in the Mountains
# 4      12240.0    1.0      0.0                       Villagers in the Woods
#
#    width
# 0  16.93
# 1  10.43
# 2    NaN
# 3  15.55
# 4  18.82
#
# [5 rows x 22 columns]

# %%
# add an column of nan called 'sales_price_usd'
df['sales_price_usd'] = np.nan
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Binhong Huang   05/30/2017     Christies        Hong Kong        1364
# 1  Binhong Huang   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Binhong Huang   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... high_estimate  \
# 0    paper     NaN  1947-01-01 00:00:00      USD    0.0  ...       64150.0
# 1    paper     NaN  1990-01-01 00:00:00      USD    0.0  ...       64150.0
# 2    paper     NaN                  NaN      USD    0.0  ...       23090.0
# 3    paper     NaN                  NaN      USD    0.0  ...      449050.0
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...       12830.0
#
#   inscribed  low_estimate                      medium  sales_price  signed  \
# 0       1.0       38490.0  watercolor and ink / paper      45900.0     1.0
# 1       1.0       38490.0  watercolor and ink / paper          0.0     1.0
# 2       1.0       15400.0  watercolor and ink / paper      22950.0     1.0
# 3       1.0      320750.0  watercolor and ink / paper     433330.0     1.0
# 4       1.0       10260.0  watercolor and ink / paper      12240.0     1.0
#
#   stamped                                        title  width  sales_price_usd
# 0     0.0                              Misty Landscape  16.93              NaN
# 1     0.0                Conversations in the Mountain  10.43              NaN
# 2     0.0  Peony and Insects / Peony and Butterfly (2)    NaN              NaN
# 3     0.0                     Retreat in the Mountains  15.55              NaN
# 4     0.0                       Villagers in the Woods  18.82              NaN
#
# [5 rows x 23 columns]

# %%
# Apparently GRD, ESP, TWD, YUM, UAH are not supported by the currency converter package
# How many rows have these currencies?
df[df['currency'].isin(['GRD', 'ESP', 'TWD', 'YUM', 'UAH', 'VEB', 'AED'])]
# Out:
#                    artist auction_date       auction_house  \
# 13460      Albrecht Dürer   12/02/2008          Christies
# 13492      Albrecht Dürer   12/02/2008          Christies
# 14498        André Derain   05/20/2011          Christies
# 15091         Andy Warhol   04/30/2008          Christies
# 15665         Andy Warhol   04/30/2008          Christies
# ...                   ...          ...                 ...
# 53773  Zhu (ju Ming) Ming   06/01/2014  Ravenel Art Group
# 53775  Zhu (ju Ming) Ming   06/01/2014  Ravenel Art Group
# 53784  Zhu (ju Ming) Ming   12/05/2010  Ravenel Art Group
# 53798  Zhu (ju Ming) Ming   06/05/2011  Ravenel Art Group
# 53807  Zhu (ju Ming) Ming   12/04/2011  Ravenel Art Group
#
#                           auction_location auction_lot category  \
# 13460   United Kingdom: London King Street          20      NaN
# 13492   United Kingdom: London King Street          21      NaN
# 14498                        France: Paris          53      NaN
# 15091          United Arab Emirates: Dubai         133      NaN
# 15665          United Arab Emirates: Dubai         134      NaN
# ...                                    ...         ...      ...
# 53773                       Taiwan: Taipei         199      NaN
# 53775                       Taiwan: Taipei         201      NaN
# 53784                       Taiwan: Taipei         156      NaN
# 53798                       Taiwan: Taipei         149      NaN
# 53807                       Taiwan: Taipei         200      NaN
#
#                         country              created currency  dated  ...  \
# 13460                   Germany                  NaN      GRD    0.0  ...
# 13492                   Germany                  NaN      GRD    0.0  ...
# 14498                    France  1904-01-01 00:00:00      ESP    1.0  ...
# 15091  United States of America  1977-01-01 00:00:00      AED    1.0  ...
# 15665  United States of America  1978-01-01 00:00:00      AED    1.0  ...
# ...                         ...                  ...      ...    ...  ...
# 53773                    Taiwan  1982-01-01 00:00:00      TWD    1.0  ...
# 53775                    Taiwan  1991-01-01 00:00:00      TWD    1.0  ...
# 53784                    Taiwan  1992-01-01 00:00:00      TWD    1.0  ...
# 53798                    Taiwan  1992-01-01 00:00:00      TWD    1.0  ...
# 53807                    Taiwan  1995-01-01 00:00:00      TWD    1.0  ...
#
#       high_estimate inscribed  low_estimate                           medium  \
# 13460       80000.0       0.0       60000.0                       Engraving
# 13492       50000.0       0.0       30000.0                       Engraving
# 14498       70000.0       0.0       50000.0                     Oil on paper
# 15091           NaN       0.0           NaN  Screenprint on Curtis Rag paper
# 15665           NaN       0.0           NaN  Screenprint on Curtis Rag paper
# ...             ...       ...           ...                              ...
# 53773     4000000.0       0.0     2800000.0                Sculpture on wood
# 53775     4000000.0       0.0     2800000.0                          Bronze
# 53784     6000000.0       0.0     4800000.0                       Sculpture
# 53798     8000000.0       0.0     6000000.0                Sculpture on wood
# 53807     4500000.0       0.0     3500000.0                          Bronze
#
#        sales_price  signed stamped  \
# 13460     145250.0     0.0     0.0
# 13492      82850.0     0.0     0.0
# 14498      85000.0     1.0     0.0
# 15091     121000.0     1.0     0.0
# 15665     157000.0     1.0     0.0
# ...            ...     ...     ...
# 53773          0.0     0.0     0.0
# 53775          0.0     0.0     0.0
# 53784          0.0     0.0     0.0
# 53798          0.0     0.0     0.0
# 53807          0.0     0.0     0.0
#
#                                                    title  width  \
# 13460          Adam and Eve (B., M., Holl. 1; S.M.S. 39)   7.56
# 13492  Saint Jerome in his Study (B. 60; M., Holl. 59...   7.36
# 14498                           Nature morte au pot bleu  13.11
# 15091                                Farah Dibah Pahlavi  45.00
# 15665          Mohammed Reza Shah Pahlavi (Shah of Iran)  34.84
# ...                                                  ...    ...
# 53773                    Taichi Series – Underarm Strike   5.91
# 53775                                      Taichi Series  12.20
# 53784                                      Taichi Series  14.57
# 53798                                      Taichi Series  12.60
# 53807                                      Taichi Series  35.43
#
#        sales_price_usd
# 13460              NaN
# 13492              NaN
# 14498              NaN
# 15091              NaN
# 15665              NaN
# ...                ...
# 53773              NaN
# 53775              NaN
# 53784              NaN
# 53798              NaN
# 53807              NaN
#
# [81 rows x 23 columns]

# %%
#81 Total, not so bad but let's keep it in mind
# Drop these rows
df = df[~df['currency'].isin(['GRD', 'ESP', 'TWD', 'YUM', 'UAH', 'VEB', 'AED'])]

# %%
#loop through the rows and convert the sales price to usd using an aribitrairy date -> today's
for index, row in df.iterrows():
    if row['currency'] != 'USD':     #only if the currency is NOT USD already
        df.loc[index, 'sales_price_usd'] = c.convert(row['sales_price'], row['currency'], 'USD', date=date(2022, 10, 7))
    else:
        df.loc[index, 'sales_price_usd'] = row['sales_price']

#check the new column
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Binhong Huang   05/30/2017     Christies        Hong Kong        1364
# 1  Binhong Huang   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Binhong Huang   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... high_estimate  \
# 0    paper     NaN  1947-01-01 00:00:00      USD    0.0  ...       64150.0
# 1    paper     NaN  1990-01-01 00:00:00      USD    0.0  ...       64150.0
# 2    paper     NaN                  NaN      USD    0.0  ...       23090.0
# 3    paper     NaN                  NaN      USD    0.0  ...      449050.0
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...       12830.0
#
#   inscribed  low_estimate                      medium  sales_price  signed  \
# 0       1.0       38490.0  watercolor and ink / paper      45900.0     1.0
# 1       1.0       38490.0  watercolor and ink / paper          0.0     1.0
# 2       1.0       15400.0  watercolor and ink / paper      22950.0     1.0
# 3       1.0      320750.0  watercolor and ink / paper     433330.0     1.0
# 4       1.0       10260.0  watercolor and ink / paper      12240.0     1.0
#
#   stamped                                        title  width  sales_price_usd
# 0     0.0                              Misty Landscape  16.93          45900.0
# 1     0.0                Conversations in the Mountain  10.43              0.0
# 2     0.0  Peony and Insects / Peony and Butterfly (2)    NaN          22950.0
# 3     0.0                     Retreat in the Mountains  15.55         433330.0
# 4     0.0                       Villagers in the Woods  18.82          12240.0
#
# [5 rows x 23 columns]

# %%
# Now let's try to convert using the date of the auction

# First we need to convert the auction date column to datetime

#Some issues
#Looks like some rows have a range of dates for when the auction was held: Like 04/01/2020-04/16/2020

#Lets see which ones have this problem
df[df['auction_date'].str.contains('-')]

# Change the date for all these rows, keep only the first day of the range
df['auction_date'] = df['auction_date'].str.split('-').str[0]
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Binhong Huang   05/30/2017     Christies        Hong Kong        1364
# 1  Binhong Huang   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Binhong Huang   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... high_estimate  \
# 0    paper     NaN  1947-01-01 00:00:00      USD    0.0  ...       64150.0
# 1    paper     NaN  1990-01-01 00:00:00      USD    0.0  ...       64150.0
# 2    paper     NaN                  NaN      USD    0.0  ...       23090.0
# 3    paper     NaN                  NaN      USD    0.0  ...      449050.0
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...       12830.0
#
#   inscribed  low_estimate                      medium  sales_price  signed  \
# 0       1.0       38490.0  watercolor and ink / paper      45900.0     1.0
# 1       1.0       38490.0  watercolor and ink / paper          0.0     1.0
# 2       1.0       15400.0  watercolor and ink / paper      22950.0     1.0
# 3       1.0      320750.0  watercolor and ink / paper     433330.0     1.0
# 4       1.0       10260.0  watercolor and ink / paper      12240.0     1.0
#
#   stamped                                        title  width  sales_price_usd
# 0     0.0                              Misty Landscape  16.93          45900.0
# 1     0.0                Conversations in the Mountain  10.43              0.0
# 2     0.0  Peony and Insects / Peony and Butterfly (2)    NaN          22950.0
# 3     0.0                     Retreat in the Mountains  15.55         433330.0
# 4     0.0                       Villagers in the Woods  18.82          12240.0
#
# [5 rows x 23 columns]

# %%
# Now convert to datetime
df['auction_date'] = pd.to_datetime(df['auction_date'])

# %%
#loop through the rows and convert the sales price to usd using the date of the auction

c = CurrencyConverter(fallback_on_missing_rate=True, fallback_on_wrong_date=True)
for index, row in df.iterrows():
    if row['currency'] != 'USD':     #only the currency is NOT USD already
        df.loc[index, 'sales_price_usd'] = c.convert(row['sales_price'], row['currency'], 'USD', date=row['auction_date'])
    else:
        df.loc[index, 'sales_price_usd'] = row['sales_price']

#There were some errors here, mainly because:
# 1) the currency converter package doesn't have the currency for that specific date
# 2) the currency converter package doesn't have the currency for that year, sometimes it only has it for the last 10 years

# This was solved by using the fallback_on_missing_rate and fallback_on_wrong_date parameters
# What these do is that they will do linear interpolation when possible, and use the closest known rate otherwise
# I guess that's good enough

#check the new column
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Binhong Huang   2017-05-30     Christies        Hong Kong        1364
# 1  Binhong Huang   2017-05-30     Christies        Hong Kong        1365
# 2       Yun Tang   2017-05-30     Christies        Hong Kong        1366
# 3  Binhong Huang   2017-05-30     Christies        Hong Kong        1367
# 4       Yun Tang   2017-05-30     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... high_estimate  \
# 0    paper     NaN  1947-01-01 00:00:00      USD    0.0  ...       64150.0
# 1    paper     NaN  1990-01-01 00:00:00      USD    0.0  ...       64150.0
# 2    paper     NaN                  NaN      USD    0.0  ...       23090.0
# 3    paper     NaN                  NaN      USD    0.0  ...      449050.0
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...       12830.0
#
#   inscribed  low_estimate                      medium  sales_price  signed  \
# 0       1.0       38490.0  watercolor and ink / paper      45900.0     1.0
# 1       1.0       38490.0  watercolor and ink / paper          0.0     1.0
# 2       1.0       15400.0  watercolor and ink / paper      22950.0     1.0
# 3       1.0      320750.0  watercolor and ink / paper     433330.0     1.0
# 4       1.0       10260.0  watercolor and ink / paper      12240.0     1.0
#
#   stamped                                        title  width  sales_price_usd
# 0     0.0                              Misty Landscape  16.93          45900.0
# 1     0.0                Conversations in the Mountain  10.43              0.0
# 2     0.0  Peony and Insects / Peony and Butterfly (2)    NaN          22950.0
# 3     0.0                     Retreat in the Mountains  15.55         433330.0
# 4     0.0                       Villagers in the Woods  18.82          12240.0
#
# [5 rows x 23 columns]

# %%
# Now we should do the same for the low_estimate and high_estimate columns

# How many rows have null values in the estimate columns?
df['low_estimate'].isnull().sum()
df['high_estimate'].isnull().sum()
# Out:
# 2084

# %%
# Drop the rows with null values in the estimate columns
df = df.dropna(subset=['low_estimate'])
df = df.dropna(subset=['high_estimate'])

# %%
# Create empty columns for the low and high estimates in USD
df['low_estimate_usd'] = np.nan
df['high_estimate_usd'] = np.nan

# %%
# Now let's try to convert using the date of the auction

#loop through the rows and convert the low_estimate to usd using the date of the auction
for index, row in df.iterrows():
    if row['currency'] != 'USD':     #only the currency is NOT USD already
        df.loc[index, 'low_estimate_usd'] = c.convert(row['low_estimate'], row['currency'], 'USD', date=row['auction_date'])
    else:
        df.loc[index, 'low_estimate_usd'] = row['low_estimate']

#loop through the rows and convert the high_estimate to usd using the date of the auction
for index, row in df.iterrows():
    if row['currency'] != 'USD':     #only the currency is NOT USD already
        df.loc[index, 'high_estimate_usd'] = c.convert(row['high_estimate'], row['currency'], 'USD', date=row['auction_date'])
    else: 
        df.loc[index, 'high_estimate_usd'] = row['high_estimate']


#check the new column
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Binhong Huang   2017-05-30     Christies        Hong Kong        1364
# 1  Binhong Huang   2017-05-30     Christies        Hong Kong        1365
# 2       Yun Tang   2017-05-30     Christies        Hong Kong        1366
# 3  Binhong Huang   2017-05-30     Christies        Hong Kong        1367
# 4       Yun Tang   2017-05-30     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... low_estimate  \
# 0    paper     NaN  1947-01-01 00:00:00      USD    0.0  ...      38490.0
# 1    paper     NaN  1990-01-01 00:00:00      USD    0.0  ...      38490.0
# 2    paper     NaN                  NaN      USD    0.0  ...      15400.0
# 3    paper     NaN                  NaN      USD    0.0  ...     320750.0
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...      10260.0
#
#                        medium  sales_price  signed  stamped  \
# 0  watercolor and ink / paper      45900.0     1.0      0.0
# 1  watercolor and ink / paper          0.0     1.0      0.0
# 2  watercolor and ink / paper      22950.0     1.0      0.0
# 3  watercolor and ink / paper     433330.0     1.0      0.0
# 4  watercolor and ink / paper      12240.0     1.0      0.0
#
#                                          title  width  sales_price_usd  \
# 0                              Misty Landscape  16.93          45900.0
# 1                Conversations in the Mountain  10.43              0.0
# 2  Peony and Insects / Peony and Butterfly (2)    NaN          22950.0
# 3                     Retreat in the Mountains  15.55         433330.0
# 4                       Villagers in the Woods  18.82          12240.0
#
#    low_estimate_usd  high_estimate_usd
# 0           38490.0            64150.0
# 1           38490.0            64150.0
# 2           15400.0            23090.0
# 3          320750.0           449050.0
# 4           10260.0            12830.0
#
# [5 rows x 25 columns]

# %%
# Export this new dataframe to a csv file to explore other stuff
df.to_csv('cleaned_data_with_usd.csv', index=False)

# %% [markdown]
# # Standardize Medium

# %%
# Let's see how many there are
df['medium'].nunique()
# Out:
# 8368

# %%
# Let's explore the medium column
df.groupby('medium').count()

# There are a lot of different mediums, are we going to try to classify them all?
# NLP? 
# Keep key words only? How many categories?
# Out:
#                                                     artist  auction_date  \
# medium
# ,gold leaf, collage and canvas / board                   1             1
# 132 drawn paper receipts of variable size pinne...       1             1
# 18-carat yellow gold with multi-colored enamel ...       1             1
# 23 carat repousse-cisele gold                            2             2
# 23 carat repoussé-ciselé gold                            1             1
# ...                                                    ...           ...
# wooden frames and cotton strings                         1             1
# wooden stool                                             1             1
# woodwith original box and wooden certificate of...       1             1
# woven canvas                                             1             1
# zinc alloys                                              1             1
#
#                                                     auction_house  \
# medium
# ,gold leaf, collage and canvas / board                          1
# 132 drawn paper receipts of variable size pinne...              1
# 18-carat yellow gold with multi-colored enamel ...              1
# 23 carat repousse-cisele gold                                   2
# 23 carat repoussé-ciselé gold                                   1
# ...                                                           ...
# wooden frames and cotton strings                                1
# wooden stool                                                    1
# woodwith original box and wooden certificate of...              1
# woven canvas                                                    1
# zinc alloys                                                     1
#
#                                                     auction_location  \
# medium
# ,gold leaf, collage and canvas / board                             1
# 132 drawn paper receipts of variable size pinne...                 1
# 18-carat yellow gold with multi-colored enamel ...                 1
# 23 carat repousse-cisele gold                                      2
# 23 carat repoussé-ciselé gold                                      1
# ...                                                              ...
# wooden frames and cotton strings                                   1
# wooden stool                                                       1
# woodwith original box and wooden certificate of...                 1
# woven canvas                                                       1
# zinc alloys                                                        1
#
#                                                     auction_lot  category  \
# medium
# ,gold leaf, collage and canvas / board                        1         1
# 132 drawn paper receipts of variable size pinne...            1         1
# 18-carat yellow gold with multi-colored enamel ...            1         1
# 23 carat repousse-cisele gold                                 2         2
# 23 carat repoussé-ciselé gold                                 1         1
# ...                                                         ...       ...
# wooden frames and cotton strings                              1         1
# wooden stool                                                  1         1
# woodwith original box and wooden certificate of...            1         1
# woven canvas                                                  1         1
# zinc alloys                                                   1         1
#
#                                                     country  created  \
# medium
# ,gold leaf, collage and canvas / board                    0        1
# 132 drawn paper receipts of variable size pinne...        0        1
# 18-carat yellow gold with multi-colored enamel ...        0        1
# 23 carat repousse-cisele gold                             0        2
# 23 carat repoussé-ciselé gold                             0        1
# ...                                                     ...      ...
# wooden frames and cotton strings                          0        1
# wooden stool                                              0        1
# woodwith original box and wooden certificate of...        0        1
# woven canvas                                              0        1
# zinc alloys                                               0        1
#
#                                                     currency  dated  ...  \
# medium                                                               ...
# ,gold leaf, collage and canvas / board                     1      1  ...
# 132 drawn paper receipts of variable size pinne...         1      0  ...
# 18-carat yellow gold with multi-colored enamel ...         1      1  ...
# 23 carat repousse-cisele gold                              2      2  ...
# 23 carat repoussé-ciselé gold                              1      1  ...
# ...                                                      ...    ...  ...
# wooden frames and cotton strings                           1      1  ...
# wooden stool                                               1      0  ...
# woodwith original box and wooden certificate of...         1      1  ...
# woven canvas                                               1      1  ...
# zinc alloys                                                1      1  ...
#
#                                                     height  high_estimate  \
# medium
# ,gold leaf, collage and canvas / board                   1              1
# 132 drawn paper receipts of variable size pinne...       0              1
# 18-carat yellow gold with multi-colored enamel ...       1              1
# 23 carat repousse-cisele gold                            2              2
# 23 carat repoussé-ciselé gold                            1              1
# ...                                                    ...            ...
# wooden frames and cotton strings                         1              1
# wooden stool                                             1              1
# woodwith original box and wooden certificate of...       1              1
# woven canvas                                             1              1
# zinc alloys                                              1              1
#
#                                                     inscribed  low_estimate  \
# medium
# ,gold leaf, collage and canvas / board                      1             1
# 132 drawn paper receipts of variable size pinne...          0             1
# 18-carat yellow gold with multi-colored enamel ...          1             1
# 23 carat repousse-cisele gold                               2             2
# 23 carat repoussé-ciselé gold                               1             1
# ...                                                       ...           ...
# wooden frames and cotton strings                            1             1
# wooden stool                                                0             1
# woodwith original box and wooden certificate of...          1             1
# woven canvas                                                1             1
# zinc alloys                                                 1             1
#
#                                                     sales_price  signed  \
# medium
# ,gold leaf, collage and canvas / board                        1       1
# 132 drawn paper receipts of variable size pinne...            1       0
# 18-carat yellow gold with multi-colored enamel ...            1       1
# 23 carat repousse-cisele gold                                 2       2
# 23 carat repoussé-ciselé gold                                 1       1
# ...                                                         ...     ...
# wooden frames and cotton strings                              1       1
# wooden stool                                                  1       0
# woodwith original box and wooden certificate of...            1       1
# woven canvas                                                  1       1
# zinc alloys                                                   1       1
#
#                                                     stamped  title  width  \
# medium
# ,gold leaf, collage and canvas / board                    1      1      1
# 132 drawn paper receipts of variable size pinne...        0      1      0
# 18-carat yellow gold with multi-colored enamel ...        1      1      1
# 23 carat repousse-cisele gold                             2      2      2
# 23 carat repoussé-ciselé gold                             1      1      1
# ...                                                     ...    ...    ...
# wooden frames and cotton strings                          1      1      1
# wooden stool                                              0      1      1
# woodwith original box and wooden certificate of...        1      1      1
# woven canvas                                              1      1      1
# zinc alloys                                               1      1      1
#
#                                                     sales_price_usd
# medium
# ,gold leaf, collage and canvas / board                            1
# 132 drawn paper receipts of variable size pinne...                1
# 18-carat yellow gold with multi-colored enamel ...                1
# 23 carat repousse-cisele gold                                     2
# 23 carat repoussé-ciselé gold                                     1
# ...                                                             ...
# wooden frames and cotton strings                                  1
# wooden stool                                                      1
# woodwith original box and wooden certificate of...                1
# woven canvas                                                      1
# zinc alloys                                                       1
#
# [8368 rows x 22 columns]

# %% [markdown]
# # Country

# %%
# How many cells without country?
df[df['country'].isnull()]
# Out:
#                                   artist auction_date auction_house  \
# 0                          Binhong Huang   05/30/2017     Christies
# 1                          Binhong Huang   05/30/2017     Christies
# 2                               Yun Tang   05/30/2017     Christies
# 3                          Binhong Huang   05/30/2017     Christies
# 4                               Yun Tang   05/30/2017     Christies
# ...                                  ...          ...           ...
# 51044  Willem Van Tetrode (attribued To)   01/30/2014     Sothebys
# 51257            William Scrots (school)   07/04/2012     Sothebys
# 53522                          Zhou Chen   11/26/2012    Christies
# 53523                          Zhou Chen   11/28/2011    Christies
# 53524                          Zhou Chen   05/27/2013    Christies
#
#                    auction_location auction_lot category country  \
# 0                         Hong Kong        1364    paper     NaN
# 1                         Hong Kong        1365    paper     NaN
# 2                         Hong Kong        1366    paper     NaN
# 3                         Hong Kong        1367    paper     NaN
# 4                         Hong Kong        1368    paper     NaN
# ...                             ...         ...      ...     ...
# 51044   The United States: New York         116      NaN     NaN
# 51257        United Kingdom: London          10      NaN     NaN
# 53522              China: Hong Kong         818      NaN     NaN
# 53523              China: Hong Kong        1702      NaN     NaN
# 53524              China: Hong Kong         741      NaN     NaN
#
#                    created currency  dated  ... high_estimate inscribed  \
# 0      1947-01-01 00:00:00      USD    0.0  ...       64150.0       1.0
# 1      1990-01-01 00:00:00      USD    0.0  ...       64150.0       1.0
# 2                      NaN      USD    0.0  ...       23090.0       1.0
# 3                      NaN      USD    0.0  ...      449050.0       1.0
# 4      1940-01-01 00:00:00      USD    0.0  ...       12830.0       1.0
# ...                    ...      ...    ...  ...           ...       ...
# 51044                  NaN      USD    0.0  ...     1200000.0       0.0
# 51257                  NaN      GBP    0.0  ...      700000.0       0.0
# 53522                  NaN      HKD    0.0  ...      400000.0       0.0
# 53523                  NaN      HKD    0.0  ...      300000.0       0.0
# 53524                  NaN      HKD    0.0  ...    10000000.0       0.0
#
#        low_estimate                      medium  sales_price  signed stamped  \
# 0           38490.0  watercolor and ink / paper      45900.0     1.0     0.0
# 1           38490.0  watercolor and ink / paper          0.0     1.0     0.0
# 2           15400.0  watercolor and ink / paper      22950.0     1.0     0.0
# 3          320750.0  watercolor and ink / paper     433330.0     1.0     0.0
# 4           10260.0  watercolor and ink / paper      12240.0     1.0     0.0
# ...             ...                         ...          ...     ...     ...
# 51044      800000.0                     Bronze           0.0     0.0     0.0
# 51257      500000.0                Oil on panel          0.0     0.0     0.0
# 53522      300000.0                Ink on paper          0.0     0.0     0.0
# 53523      200000.0                Ink on paper          0.0     0.0     0.0
# 53524     8000000.0                 Ink on silk          0.0     1.0     0.0
#
#                                              title   width  sales_price_usd
# 0                                  Misty Landscape   16.93          45900.0
# 1                    Conversations in the Mountain   10.43              0.0
# 2      Peony and Insects / Peony and Butterfly (2)     NaN          22950.0
# 3                         Retreat in the Mountains   15.55         433330.0
# 4                           Villagers in the Woods   18.82          12240.0
# ...                                            ...     ...              ...
# 51044                SAMSON SLAYING THE PHILISTINE    0.00              0.0
# 51257            PORTRAIT OF EDWARD VI (1537-1553)   27.95              0.0
# 53522                      Fishing in a Quiet Lake   21.65              0.0
# 53523                       Pavilions by the River   18.74              0.0
# 53524                                River Scenery  804.33              0.0
#
# [12920 rows x 23 columns]

# %%
# So, 12920 rows without country, how many artists?
df[df['country'].isnull()].groupby('artist').size().sort_values(ascending=False)

# 1928 artists, hopefully only a few of them make up most of the rows
# Out:
# artist
# Ru Pu                       248
# Daqian Zhang                245
# Yayoi Kusama                245
# Wou-Ki Zao                  210
# Le Pho                      209
#                            ...
# Luo Erchun                    1
# Luo Quanmu                    1
# Luo Song                      1
# Luo Wang                      1
# ou & Zhu Haonian & Mulan      1
# Length: 1928, dtype: int64

# %%
# How to recover the country?
# Maybe we can use the artist's name and search for it on wikipedia?

# Let's try wikipedia and one artist only for now
import wikipedia
wikipedia.set_lang("en")
wikipedia.search("Yayoi Kusama")
# Okay she can be found on wikipedia

page = wikipedia.page("Yayoi Kusama")
page.content[:1000] # print the first 1000 characters
# Out:
# 'Yayoi Kusama (草間 彌生, Kusama Yayoi, born 22 March 1929) is a Japanese contemporary artist who works primarily in sculpture and installation, but is also active in painting, performance, video art, fashion, poetry, fiction, and other arts. Her work is based in conceptual art and shows some attributes of feminism, minimalism, surrealism, Art Brut, pop art, and abstract expressionism, and is infused with autobiographical, psychological, and sexual content. She has been acknowledged as one of the most important living artists to come out of Japan.Kusama was raised in Matsumoto, and trained at the Kyoto City University of Arts in a traditional Japanese painting style called nihonga. Kusama was inspired, however, by American Abstract impressionism. She moved to New York City in 1958 and was a part of the New York avant-garde scene throughout the 1960s, especially in the pop-art movement. Embracing the rise of the hippie counterculture of the late 1960s, she came to public attention when she o'

# %%
#How to extract the country from the page content?
#Let's try to find the word 'nationality' and then get the next word
page.content.find('born in')

## uffff man this looks like a lot of work, let's try to find a better way
# Out:
# -1
