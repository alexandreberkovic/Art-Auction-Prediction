# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import xlrd
warnings.filterwarnings('ignore')

# %% [markdown]
# # Further Pre Processing - Standardize Currency - Medium - Country

# %%
#import clean data
df = pd.read_csv('cleaned_data.csv')
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Huang Binhong   05/30/2017     Christies        Hong Kong        1364
# 1  Huang Binhong   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Huang Binhong   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... low_estimate  \
# 0    paper   China  1947-01-01 00:00:00      USD    0.0  ...      38490.0
# 1    paper   China  1990-01-01 00:00:00      USD    0.0  ...      38490.0
# 2    paper     NaN                  NaN      USD    0.0  ...      15400.0
# 3    paper   China                  NaN      USD    0.0  ...     320750.0
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...      10260.0
#
#                        medium  sales_price  signed  stamped  \
# 0  watercolor and ink / paper      45900.0     1.0      0.0
# 1  watercolor and ink / paper          0.0     1.0      0.0
# 2  watercolor and ink / paper      22950.0     1.0      0.0
# 3  watercolor and ink / paper     433330.0     1.0      0.0
# 4  watercolor and ink / paper      12240.0     1.0      0.0
#
#                                          title  width  aspect_ratio    area  \
# 0                              Misty Landscape  16.93          1.99  569.86
# 1                Conversations in the Mountain  10.43          1.30  141.64
# 2  Peony and Insects / Peony and Butterfly (2)    NaN           NaN     NaN
# 3                     Retreat in the Mountains  15.55          2.63  636.62
# 4                       Villagers in the Woods  18.82          2.10  743.95
#
#    sold
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Standardize Currency

# %%
#how many unique currencies are there?
df['currency'].nunique()
# Out:
# 28

# %%
#What are the most common
df['currency'].value_counts().head(10)
# Out:
# USD    28954
# GBP    14062
# EUR     4560
# HKD     3045
# CHF      322
# SEK      199
# CNY      167
# AUD      139
# CAD      119
# NOK       64
# Name: currency, dtype: int64

# %%
# Are there any rows with null currency values?
df[df['currency'].isnull()]
# Out:
#                    artist auction_date                  auction_house  \
# 12275     Adolph Gottlieb   05/13/2008                     Christies
# 12291     Adolph Gottlieb   05/14/2008                     Christies
# 12320     Adolph Gottlieb   05/22/2007        Bonhams & Butterfields
# 12337      Adriaen Coorte   03/28/2014  Hampel Fine Art Auctioneers
# 12350     Adriana Varejão   09/22/2011                 Bolsa De Arte
# ...                   ...          ...                            ...
# 53831  Zhu (ju Ming) Ming   05/25/2008                     Christies
# 53834  Zhu (ju Ming) Ming   05/25/2008                     Christies
# 53838  Zhu (ju Ming) Ming   05/25/2008                     Christies
# 53843  Zhu (ju Ming) Ming   05/25/2008                     Christies
# 53845  Zhu (ju Ming) Ming   05/25/2008                     Christies
#
#                                       auction_location auction_lot   category  \
# 12275   The United States: New York Rockefeller Center          22   painting
# 12291   The United States: New York Rockefeller Center         146      paper
# 12320      The United States: California San Francisco          60      paper
# 12337                                  Germany: Munich        1097      paper
# 12350                           Brasil: Rio de Janeiro          44   painting
# ...                                                ...         ...        ...
# 53831                                 China: Hong Kong         311  sculpture
# 53834                                 China: Hong Kong         278  sculpture
# 53838                                 China: Hong Kong         313  sculpture
# 53843                                 China: Hong Kong         281  sculpture
# 53845                                 China: Hong Kong         279  sculpture
#
#                         country              created currency  dated  ...  \
# 12275  United States of America                  NaN      NaN    0.0  ...
# 12291  United States of America  1946-01-01 00:00:00      NaN    1.0  ...
# 12320  United States of America  1949-01-01 00:00:00      NaN    1.0  ...
# 12337                       NaN                  NaN      NaN    0.0  ...
# 12350                    Brazil  2001-01-01 00:00:00      NaN    1.0  ...
# ...                         ...                  ...      ...    ...  ...
# 53831                    Taiwan  1994-01-01 00:00:00      NaN    1.0  ...
# 53834                    Taiwan  1991-01-01 00:00:00      NaN    1.0  ...
# 53838                    Taiwan  1991-01-01 00:00:00      NaN    1.0  ...
# 53843                    Taiwan  1995-01-01 00:00:00      NaN    1.0  ...
# 53845                    Taiwan                  NaN      NaN    0.0  ...
#
#       low_estimate                                    medium  sales_price  \
# 12275          NaN                             oil on canvas    6537000.0
# 12291          NaN  gouache watercolor and graphite on paper     145000.0
# 12320          NaN                          gouache on paper      70000.0
# 12337          NaN                              oil on paper     145000.0
# 12350          NaN                             oil on canvas    1011236.0
# ...            ...                                       ...          ...
# 53831          NaN                          bronze sculpture     907500.0
# 53834          NaN                            wood sculpture    1327500.0
# 53838          NaN                                sculpture     1927500.0
# 53843          NaN                            sculpture wood    3007500.0
# 53845          NaN                            wood sculpture    4207500.0
#
#        signed  stamped                                        title  width  \
# 12275     1.0      0.0                                   Cool Blast  70.00
# 12291     1.0      0.0                                  Mood Indigo  19.49
# 12320     1.0      0.0                                     Untitled  19.25
# 12337     1.0      0.0  STILL LIFE WITH SEA SHELLS ON A STONE PLATE   8.07
# 12350     1.0      0.0                                Macau Wall #5  39.37
# ...       ...      ...                                          ...    ...
# 53831     1.0      0.0                     Taiji Series - Push Hand  12.99
# 53834     1.0      0.0                   Taiji Series - Single Whip  15.75
# 53838     1.0      0.0                   Taiji Series - Single Whip  23.62
# 53843     1.0      0.0                   Taiji Series - Single Whip  27.56
# 53845     0.0      0.0                   Taiji Series - Single Whip  25.98
#
#        aspect_ratio     area  sold
# 12275          1.29  6300.00     1
# 12291          1.31   496.41     1
# 12320          1.33   491.07     1
# 12337          0.70    45.43     1
# 12350          1.00  1550.00     1
# ...             ...      ...   ...
# 53831          1.85   312.02     1
# 53834          0.70   173.56     1
# 53838          0.53   297.61     1
# 53843          1.00   759.55     1
# 53845          2.12  1428.90     1
#
# [2075 rows x 25 columns]

# %%
# First, let's see what the most common auction locations are for rows with null currency values
df[df['currency'].isnull()].auction_location.value_counts().head(10)
# Out:
#  Bern                                              363
#  The United States: New York Rockefeller Center    338
#  United Kingdom: London New Bond Street            219
#  Germany: Munich                                   208
#  China: Hong Kong                                  134
#  France: Paris                                      69
#  Germany: Hamburg                                   57
#  Germany: Cologne                                   50
#  United Kingdom: London King Street                 50
#  Hong Kong                                          44
# Name: auction_location, dtype: int64

# %%
# Lets create a temporary column with the auction location country
df['auction_location_country'] = df['auction_location'].str.split(':').str[0]
#Clean any spaces
df['auction_location_country'] = df['auction_location_country'].str.strip()

# See how it looks
df[df['currency'].isnull()].auction_location_country.value_counts().head(10)
# Out:
# The United States           500
# Germany                     364
# Bern                        363
# United Kingdom              321
# China                       135
# France                       88
# United States of America     50
# Hong Kong                    46
# Ireland                      35
# Italy                        25
# Name: auction_location_country, dtype: int64

# %%
# See how this package works
import pycountry

country = pycountry.countries.get(name='Norway')
currency = pycountry.currencies.get(numeric=country.numeric)

currency.alpha_3
# Out:
# 'NOK'

# %%
# Iterate through all the rows with null currency
for index, row in df[df['currency'].isnull()].iterrows():
    # Get the country name from the auction_location column
    auction_location_country = row['auction_location_country']

    # Try getting the country object from the pycountry package, if error, skip
    try:
        country = pycountry.countries.get(name=auction_location_country)
        # Get the currency object from the pycountry package
        currency = pycountry.currencies.get(numeric=country.numeric)
        # Set the currency column to the alpha_3 code of the currency object
        df.loc[index, 'currency'] = currency.alpha_3
    except:
        pass

# Check that we have no more null currency values
df[df['currency'].isnull()]
# Out:
#                    artist auction_date                  auction_house  \
# 12275     Adolph Gottlieb   05/13/2008                     Christies
# 12291     Adolph Gottlieb   05/14/2008                     Christies
# 12320     Adolph Gottlieb   05/22/2007        Bonhams & Butterfields
# 12337      Adriaen Coorte   03/28/2014  Hampel Fine Art Auctioneers
# 12350     Adriana Varejão   09/22/2011                 Bolsa De Arte
# ...                   ...          ...                            ...
# 52841        Zhang Daqian   12/11/2010                      Lempertz
# 53328      Zhang Xiaogang   11/20/2006        Bonhams & Butterfields
# 53335      Zhang Xiaogang   11/20/2006        Bonhams & Butterfields
# 53406      Zhang Xiaogang   05/14/2008                     Christies
# 53642  Zhu (ju Ming) Ming   11/20/2006        Bonhams & Butterfields
#
#                                       auction_location auction_lot   category  \
# 12275   The United States: New York Rockefeller Center          22   painting
# 12291   The United States: New York Rockefeller Center         146      paper
# 12320      The United States: California San Francisco          60      paper
# 12337                                  Germany: Munich        1097      paper
# 12350                           Brasil: Rio de Janeiro          44   painting
# ...                                                ...         ...        ...
# 52841                                 Germany: Cologne          72      paper
# 53328      The United States: California San Francisco        6148   painting
# 53335      The United States: California San Francisco        6147   painting
# 53406   The United States: New York Rockefeller Center         329   painting
# 53642      The United States: California San Francisco        6163  sculpture
#
#                         country              created currency  dated  ...  \
# 12275  United States of America                  NaN      NaN    0.0  ...
# 12291  United States of America  1946-01-01 00:00:00      NaN    1.0  ...
# 12320  United States of America  1949-01-01 00:00:00      NaN    1.0  ...
# 12337                       NaN                  NaN      NaN    0.0  ...
# 12350                    Brazil  2001-01-01 00:00:00      NaN    1.0  ...
# ...                         ...                  ...      ...    ...  ...
# 52841                     China  1944-01-01 00:00:00      NaN    1.0  ...
# 53328                     China  2005-01-01 00:00:00      NaN    1.0  ...
# 53335                     China  2001-01-01 00:00:00      NaN    1.0  ...
# 53406                     China  2000-01-01 00:00:00      NaN    1.0  ...
# 53642                    Taiwan  1990-01-01 00:00:00      NaN    1.0  ...
#
#                                          medium sales_price  signed  stamped  \
# 12275                             oil on canvas   6537000.0     1.0      0.0
# 12291  gouache watercolor and graphite on paper    145000.0     1.0      0.0
# 12320                          gouache on paper     70000.0     1.0      0.0
# 12337                              oil on paper    145000.0     1.0      0.0
# 12350                             oil on canvas   1011236.0     1.0      0.0
# ...                                         ...         ...     ...      ...
# 52841                              ink on paper    204000.0     1.0      0.0
# 53328                             oil on canvas    180000.0     1.0      0.0
# 53335                             oil on canvas    150000.0     1.0      0.0
# 53406                             oil on canvas    993000.0     1.0      0.0
# 53642                            wood sculpture    115000.0     1.0      0.0
#
#                                                    title  width aspect_ratio  \
# 12275                                         Cool Blast  70.00         1.29
# 12291                                        Mood Indigo  19.49         1.31
# 12320                                           Untitled  19.25         1.33
# 12337        STILL LIFE WITH SEA SHELLS ON A STONE PLATE   8.07         0.70
# 12350                                      Macau Wall #5  39.37         1.00
# ...                                                  ...    ...          ...
# 52841  Drei Gelehrte beim Brettspiel an einem bizarre...  21.77         2.06
# 53328                                 Amnesia and Memory  20.00         1.20
# 53335                                        Baby No. 19  15.75         1.25
# 53406                    Bloodline Series (Two Comrades)  39.25         0.80
# 53642                          Buffalo dragging the wood  15.75         2.80
#
#           area  sold  auction_location_country
# 12275  6300.00     1         The United States
# 12291   496.41     1         The United States
# 12320   491.07     1         The United States
# 12337    45.43     1                   Germany
# 12350  1550.00     1                    Brasil
# ...        ...   ...                       ...
# 52841   977.04     1                   Germany
# 53328   480.40     1         The United States
# 53335   311.22     1         The United States
# 53406  1232.45     1         The United States
# 53642   694.42     1         The United States
#
# [1491 rows x 26 columns]

# %%
# That didn't help much, only 500 rows were recovred, let's just create a manual dictionary for the rest
currency_dict = {
    'The United States': 'USD',
    'Germany': 'EUR',
    'Bern': 'CHF',
    'France': 'EUR',
    'United States of America': 'USD',
    'Ireland': 'EUR',
    'Italy': 'EUR',
    'Czech Republic': 'EUR',
    'Belgium': 'EUR',
    'Italia': 'EUR',
    'Brasil': 'BRL',
    'Spain': 'EUR',
    'Finland': 'EUR',
    'Lefèvre': 'EUR',
    'Austria': 'EUR',
    'Netherlands': 'EUR',
    'The Netherlands': 'EUR',
}

# Iterate through all the rows with null currency
for index, row in df[df['currency'].isnull()].iterrows():
    # Get the country name from the auction_location column
    auction_location_country = row['auction_location_country']

    # If the country is in the dictionary, set the currency column to the value
    if auction_location_country in currency_dict:
        df.loc[index, 'currency'] = currency_dict[auction_location_country]

# Check that we have no more null currency values
df[df['currency'].isnull()]
# Out:
#                                 artist auction_date  \
# 17717                   Bernard Buffet   12/06/2006
# 17944                   Brett Whiteley   07/31/2006
# 17994                   Brett Whiteley   11/27/2013
# 30331  Ivan Konstantinovich Aivazovsky   04/13/2005
# 31154             Jean Baptiste Greuze   11/17/2004
# 34518                 Jusepe De Ribera   12/04/2008
# 35458    Konstantin Egorovich Makovsky   05/19/2005
# 36596                  Lucas Cranach I   09/04/2008
# 37408         Lyonel Charles Feininger   05/06/2005
# 38093                     Marc Chagall   12/14/2012
# 48431               Samuel John Peploe   12/06/2008
# 50322                     Wang Guangyi   12/06/2009
#
#                            auction_house      auction_location auction_lot  \
# 17717                             Poette                Castor          76
# 17944                             Lawson              Menzies          343
# 17994                          Deutscher              Menzies           19
# 30331                            Chochon      Barré & Allardi           36
# 31154                           Delorme      Collin du Bocage           78
# 34518                               Kahn            Dumousset          210
# 35458  Gelos Antiques and Auction House         Russia: Moscow          35
# 36596                       Auktionshaus              Weidler          410
# 37408                Peter Kiefer • Buch   und Kunstauktionen         4962
# 38093          Hôtel des Ventes de Monte                Carlo           36
# 48431                Shapes Auctioneers    Scotland: Edinburgh         797
# 50322                 Ravenel Art Group         Taiwan: Taipei         157
#
#        category                   country              created currency  \
# 17717  painting                    France                  NaN      NaN
# 17944  painting                 Australia  1964-01-01 00:00:00      NaN
# 17994  painting                 Australia  1973-01-01 00:00:00      NaN
# 30331  painting                    Russia                  NaN      NaN
# 31154  painting                    France  1759-01-01 00:00:00      NaN
# 34518     paper                     Spain                  NaN      NaN
# 35458  painting                    Russia                  NaN      NaN
# 36596  painting                   Germany                  NaN      NaN
# 37408  painting  United States of America  1946-01-01 00:00:00      NaN
# 38093     paper                    France                  NaN      NaN
# 48431  painting                  Scotland                  NaN      NaN
# 50322  painting                     China  2002-01-01 00:00:00      NaN
#
#        dated  ...                           medium sales_price  signed  \
# 17717    0.0  ...                    oil on canvas    145000.0     1.0
# 17944    1.0  ...                        painting     204000.0     0.0
# 17994    1.0  ...                   oil on plywood    228000.0     1.0
# 30331    0.0  ...  oil on canvas mounted on carton     80000.0     0.0
# 31154    1.0  ...                    oil on canvas     80000.0     1.0
# 34518    0.0  ...    pen brown washed, on handmade    105000.0     0.0
# 35458    0.0  ...                    oil on canvas    700000.0     0.0
# 36596    0.0  ...                         tempera     112000.0     0.0
# 37408    1.0  ...                    oil on canvas    150000.0     1.0
# 38093    0.0  ...                             ink     270000.0     0.0
# 48431    0.0  ...                     oil on panel     70000.0     1.0
# 50322    1.0  ...                    oil on canvas    156716.0     1.0
#
#        stamped                                              title  width  \
# 17717      0.0                                    New York-Subway  39.37
# 17944      0.0                        Cheetah in Rillington Place  72.05
# 17994      0.0                        TO REPEAT WITHOUT REPEATING  34.65
# 30331      0.0                                    Temple en Grèce  10.24
# 31154      0.0  Portrait de César Gabriel, Duc de Choiseul Pra...  28.54
# 34518      0.0                                   Die letzte Fahrt   6.69
# 35458      0.0                            The Ceremony of Kissing  84.45
# 36596      0.0                     Apoll und Diana in  Landschaft  20.08
# 37408      0.0              Yacht race - "Racing Skerry Cruisers"  25.00
# 38093      0.0                    L&#146;écuyère au double profil  19.69
# 48431      0.0                                     Ile de Bréhart  16.14
# 50322      0.0                 Great Criticism Series - Channel V  59.06
#
#       aspect_ratio     area  sold  auction_location_country
# 17717         1.65  2557.48     1                    Castor
# 17944         1.13  5843.25     1                   Menzies
# 17994         1.01  1207.21     1                   Menzies
# 30331         0.62    64.51     1           Barré & Allardi
# 31154         1.26  1022.59     1          Collin du Bocage
# 34518         1.38    61.88     1                 Dumousset
# 35458         0.67  4787.47     1                    Russia
# 36596         1.44   580.31     1                   Weidler
# 37408         0.52   324.75     1        und Kunstauktionen
# 38093         1.33   515.48     1                     Carlo
# 48431         0.80   209.66     1                  Scotland
# 50322         0.80  2789.99     1                    Taiwan
#
# [12 rows x 26 columns]

# %%
# Okay, we went down to 12 rows with null currency values, let's just drop them
df = df.dropna(subset=['currency'])

#Drop the temporary column
df = df.drop('auction_location_country', axis=1)

# Check that we have no more null currency values
df[df['currency'].isnull()]
# Out:
# Empty DataFrame
# Columns: [artist, auction_date, auction_house, auction_location, auction_lot, category, country, created, currency, dated, edition, foundry, height, high_estimate, inscribed, low_estimate, medium, sales_price, signed, stamped, title, width, aspect_ratio, area, sold]
# Index: []
#
# [0 rows x 25 columns]

# %%
#Try out converter package
from currency_converter import CurrencyConverter
c = CurrencyConverter(fallback_on_missing_rate=True, fallback_on_wrong_date=True)
c.convert(100, 'EUR', 'USD')
# Out:
# 97.06

# %%
#Will have to convert based on the date of the auction
from datetime import date
c.convert(100, 'EUR', 'USD', date=date(2000, 1, 28))
# Out:
# 98.48

# %%
# Clean the cells
""" df['sales_price'] = df['sales_price'].str.replace('[a-zA-Z]', '')
df['sales_price'] = df['sales_price'].str.replace(',', '')
df['sales_price'] = df['sales_price'].str.replace('$', '')
df['sales_price'] = df['sales_price'].str.replace(' ', '')
df['sales_price'] = df['sales_price'].str.replace('[', '')
df['sales_price'] = df['sales_price'].str.replace(']', '') """

# If the cell is empty, fill it with 0
df['sales_price'] = df['sales_price'].fillna(0)
df['sales_price'] = df['sales_price'].replace('', 0)

# Convert to float
df['sales_price'] = df['sales_price'].astype(float)

# %%
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Binhong Huang   05/30/2017     Christies        Hong Kong        1364
# 1  Binhong Huang   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Binhong Huang   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... height  \
# 0    paper     NaN  1947-01-01 00:00:00      USD    0.0  ...  33.66
# 1    paper     NaN  1990-01-01 00:00:00      USD    0.0  ...  13.58
# 2    paper     NaN                  NaN      USD    0.0  ...    NaN
# 3    paper     NaN                  NaN      USD    0.0  ...  40.94
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...  39.53
#
#   high_estimate  inscribed  low_estimate                      medium  \
# 0       64150.0        1.0       38490.0  watercolor and ink / paper
# 1       64150.0        1.0       38490.0  watercolor and ink / paper
# 2       23090.0        1.0       15400.0  watercolor and ink / paper
# 3      449050.0        1.0      320750.0  watercolor and ink / paper
# 4       12830.0        1.0       10260.0  watercolor and ink / paper
#
#    sales_price signed  stamped                                        title  \
# 0      45900.0    1.0      0.0                              Misty Landscape
# 1          0.0    1.0      0.0                Conversations in the Mountain
# 2      22950.0    1.0      0.0  Peony and Insects / Peony and Butterfly (2)
# 3     433330.0    1.0      0.0                     Retreat in the Mountains
# 4      12240.0    1.0      0.0                       Villagers in the Woods
#
#    width
# 0  16.93
# 1  10.43
# 2    NaN
# 3  15.55
# 4  18.82
#
# [5 rows x 22 columns]

# %%
# add an column of nan called 'sales_price_usd'
df['sales_price_usd'] = np.nan
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Huang Binhong   05/30/2017     Christies        Hong Kong        1364
# 1  Huang Binhong   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Huang Binhong   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ...  \
# 0    paper   China  1947-01-01 00:00:00      USD    0.0  ...
# 1    paper   China  1990-01-01 00:00:00      USD    0.0  ...
# 2    paper     NaN                  NaN      USD    0.0  ...
# 3    paper   China                  NaN      USD    0.0  ...
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...
#
#                        medium sales_price  signed  stamped  \
# 0  watercolor and ink / paper     45900.0     1.0      0.0
# 1  watercolor and ink / paper         0.0     1.0      0.0
# 2  watercolor and ink / paper     22950.0     1.0      0.0
# 3  watercolor and ink / paper    433330.0     1.0      0.0
# 4  watercolor and ink / paper     12240.0     1.0      0.0
#
#                                          title  width aspect_ratio    area  \
# 0                              Misty Landscape  16.93         1.99  569.86
# 1                Conversations in the Mountain  10.43         1.30  141.64
# 2  Peony and Insects / Peony and Butterfly (2)    NaN          NaN     NaN
# 3                     Retreat in the Mountains  15.55         2.63  636.62
# 4                       Villagers in the Woods  18.82         2.10  743.95
#
#    sold  sales_price_usd
# 0     1              NaN
# 1     0              NaN
# 2     1              NaN
# 3     1              NaN
# 4     1              NaN
#
# [5 rows x 26 columns]

# %%
# Apparently GRD, ESP, TWD, YUM, UAH are not supported by the currency converter package
# How many rows have these currencies?
df[df['currency'].isin(['GRD', 'ESP', 'TWD', 'YUM', 'UAH', 'VEB', 'AED'])]
# Out:
#                    artist auction_date       auction_house  \
# 13456      Albrecht Dürer   12/02/2008          Christies
# 13488      Albrecht Dürer   12/02/2008          Christies
# 14494        André Derain   05/20/2011          Christies
# 15087         Andy Warhol   04/30/2008          Christies
# 15661         Andy Warhol   04/30/2008          Christies
# ...                   ...          ...                 ...
# 53769  Zhu (ju Ming) Ming   06/01/2014  Ravenel Art Group
# 53771  Zhu (ju Ming) Ming   06/01/2014  Ravenel Art Group
# 53780  Zhu (ju Ming) Ming   12/05/2010  Ravenel Art Group
# 53794  Zhu (ju Ming) Ming   06/05/2011  Ravenel Art Group
# 53803  Zhu (ju Ming) Ming   12/04/2011  Ravenel Art Group
#
#                           auction_location auction_lot   category  \
# 13456   United Kingdom: London King Street          20  sculpture
# 13488   United Kingdom: London King Street          21  sculpture
# 14494                        France: Paris          53      paper
# 15087          United Arab Emirates: Dubai         133      paper
# 15661          United Arab Emirates: Dubai         134      paper
# ...                                    ...         ...        ...
# 53769                       Taiwan: Taipei         199  sculpture
# 53771                       Taiwan: Taipei         201  sculpture
# 53780                       Taiwan: Taipei         156  sculpture
# 53794                       Taiwan: Taipei         149  sculpture
# 53803                       Taiwan: Taipei         200  sculpture
#
#                         country              created currency  dated  ...  \
# 13456                   Germany                  NaN      GRD    0.0  ...
# 13488                   Germany                  NaN      GRD    0.0  ...
# 14494                    France  1904-01-01 00:00:00      ESP    1.0  ...
# 15087  United States of America  1977-01-01 00:00:00      AED    1.0  ...
# 15661  United States of America  1978-01-01 00:00:00      AED    1.0  ...
# ...                         ...                  ...      ...    ...  ...
# 53769                    Taiwan  1982-01-01 00:00:00      TWD    1.0  ...
# 53771                    Taiwan  1991-01-01 00:00:00      TWD    1.0  ...
# 53780                    Taiwan  1992-01-01 00:00:00      TWD    1.0  ...
# 53794                    Taiwan  1992-01-01 00:00:00      TWD    1.0  ...
# 53803                    Taiwan  1995-01-01 00:00:00      TWD    1.0  ...
#
#                                 medium sales_price  signed  stamped  \
# 13456                       engraving     145250.0     0.0      0.0
# 13488                       engraving      82850.0     0.0      0.0
# 14494                     oil on paper     85000.0     1.0      0.0
# 15087  screenprint on curtis rag paper    121000.0     1.0      0.0
# 15661  screenprint on curtis rag paper    157000.0     1.0      0.0
# ...                                ...         ...     ...      ...
# 53769                sculpture on wood   3600000.0     0.0      0.0
# 53771                          bronze    3120000.0     0.0      0.0
# 53780                       sculpture    4800000.0     0.0      0.0
# 53794                sculpture on wood  10200000.0     0.0      0.0
# 53803                          bronze    3600000.0     0.0      0.0
#
#                                                    title  width aspect_ratio  \
# 13456          Adam and Eve (B., M., Holl. 1; S.M.S. 39)   7.56         1.30
# 13488  Saint Jerome in his Study (B. 60; M., Holl. 59...   7.36         1.32
# 14494                           Nature morte au pot bleu  13.11         1.25
# 15087                                Farah Dibah Pahlavi  45.00         0.78
# 15661          Mohammed Reza Shah Pahlavi (Shah of Iran)  34.84         1.29
# ...                                                  ...    ...          ...
# 53769                    Taichi Series – Underarm Strike   5.91         1.93
# 53771                                      Taichi Series  12.20         1.52
# 53780                                      Taichi Series  14.57         1.40
# 53794                                      Taichi Series  12.60         1.56
# 53803                                      Taichi Series  35.43         0.53
#
#           area  sold  sales_price_usd
# 13456    74.39     1              NaN
# 13488    71.32     1              NaN
# 14494   214.22     1              NaN
# 15087  1575.00     1              NaN
# 15661  1570.59     1              NaN
# ...        ...   ...              ...
# 53769    67.49     1              NaN
# 53771   225.70     1              NaN
# 53780   298.25     1              NaN
# 53794   248.09     1              NaN
# 53803   669.63     1              NaN
#
# [81 rows x 26 columns]

# %%
#81 Total, not so bad but let's keep it in mind
# Drop these rows
df = df[~df['currency'].isin(['GRD', 'ESP', 'TWD', 'YUM', 'UAH', 'VEB', 'AED'])]

# %%
#loop through the rows and convert the sales price to usd using an aribitrairy date -> today's
for index, row in df.iterrows():
    if row['currency'] != 'USD':     #only if the currency is NOT USD already
        df.loc[index, 'sales_price_usd'] = c.convert(row['sales_price'], row['currency'], 'USD', date=date(2022, 10, 7))
    else:
        df.loc[index, 'sales_price_usd'] = row['sales_price']

#check the new column
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Huang Binhong   05/30/2017     Christies        Hong Kong        1364
# 1  Huang Binhong   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Huang Binhong   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ...  \
# 0    paper   China  1947-01-01 00:00:00      USD    0.0  ...
# 1    paper   China  1990-01-01 00:00:00      USD    0.0  ...
# 2    paper     NaN                  NaN      USD    0.0  ...
# 3    paper   China                  NaN      USD    0.0  ...
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...
#
#                        medium sales_price  signed  stamped  \
# 0  watercolor and ink / paper     45900.0     1.0      0.0
# 1  watercolor and ink / paper         0.0     1.0      0.0
# 2  watercolor and ink / paper     22950.0     1.0      0.0
# 3  watercolor and ink / paper    433330.0     1.0      0.0
# 4  watercolor and ink / paper     12240.0     1.0      0.0
#
#                                          title  width aspect_ratio    area  \
# 0                              Misty Landscape  16.93         1.99  569.86
# 1                Conversations in the Mountain  10.43         1.30  141.64
# 2  Peony and Insects / Peony and Butterfly (2)    NaN          NaN     NaN
# 3                     Retreat in the Mountains  15.55         2.63  636.62
# 4                       Villagers in the Woods  18.82         2.10  743.95
#
#    sold  sales_price_usd
# 0     1          45900.0
# 1     0              0.0
# 2     1          22950.0
# 3     1         433330.0
# 4     1          12240.0
#
# [5 rows x 26 columns]

# %%
# Now let's try to convert using the date of the auction

# First we need to convert the auction date column to datetime

#Some issues
#Looks like some rows have a range of dates for when the auction was held: Like 04/01/2020-04/16/2020

#Lets see which ones have this problem
df[df['auction_date'].str.contains('-')]

# Change the date for all these rows, keep only the first day of the range
df['auction_date'] = df['auction_date'].str.split('-').str[0]
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Huang Binhong   05/30/2017     Christies        Hong Kong        1364
# 1  Huang Binhong   05/30/2017     Christies        Hong Kong        1365
# 2       Yun Tang   05/30/2017     Christies        Hong Kong        1366
# 3  Huang Binhong   05/30/2017     Christies        Hong Kong        1367
# 4       Yun Tang   05/30/2017     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ...  \
# 0    paper   China  1947-01-01 00:00:00      USD    0.0  ...
# 1    paper   China  1990-01-01 00:00:00      USD    0.0  ...
# 2    paper     NaN                  NaN      USD    0.0  ...
# 3    paper   China                  NaN      USD    0.0  ...
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...
#
#                        medium sales_price  signed  stamped  \
# 0  watercolor and ink / paper     45900.0     1.0      0.0
# 1  watercolor and ink / paper         0.0     1.0      0.0
# 2  watercolor and ink / paper     22950.0     1.0      0.0
# 3  watercolor and ink / paper    433330.0     1.0      0.0
# 4  watercolor and ink / paper     12240.0     1.0      0.0
#
#                                          title  width aspect_ratio    area  \
# 0                              Misty Landscape  16.93         1.99  569.86
# 1                Conversations in the Mountain  10.43         1.30  141.64
# 2  Peony and Insects / Peony and Butterfly (2)    NaN          NaN     NaN
# 3                     Retreat in the Mountains  15.55         2.63  636.62
# 4                       Villagers in the Woods  18.82         2.10  743.95
#
#    sold  sales_price_usd
# 0     1          45900.0
# 1     0              0.0
# 2     1          22950.0
# 3     1         433330.0
# 4     1          12240.0
#
# [5 rows x 26 columns]

# %%
# Now convert to datetime
df['auction_date'] = pd.to_datetime(df['auction_date'])

# %%
#loop through the rows and convert the sales price to usd using the date of the auction

c = CurrencyConverter(fallback_on_missing_rate=True, fallback_on_wrong_date=True)
for index, row in df.iterrows():
    if row['currency'] != 'USD':     #only the currency is NOT USD already
        df.loc[index, 'sales_price_usd'] = c.convert(row['sales_price'], row['currency'], 'USD', date=row['auction_date'])
    else:
        df.loc[index, 'sales_price_usd'] = row['sales_price']

#There were some errors here, mainly because:
# 1) the currency converter package doesn't have the currency for that specific date
# 2) the currency converter package doesn't have the currency for that year, sometimes it only has it for the last 10 years

# This was solved by using the fallback_on_missing_rate and fallback_on_wrong_date parameters
# What these do is that they will do linear interpolation when possible, and use the closest known rate otherwise
# I guess that's good enough

#check the new column
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Huang Binhong   2017-05-30     Christies        Hong Kong        1364
# 1  Huang Binhong   2017-05-30     Christies        Hong Kong        1365
# 2       Yun Tang   2017-05-30     Christies        Hong Kong        1366
# 3  Huang Binhong   2017-05-30     Christies        Hong Kong        1367
# 4       Yun Tang   2017-05-30     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ...  \
# 0    paper   China  1947-01-01 00:00:00      USD    0.0  ...
# 1    paper   China  1990-01-01 00:00:00      USD    0.0  ...
# 2    paper     NaN                  NaN      USD    0.0  ...
# 3    paper   China                  NaN      USD    0.0  ...
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...
#
#                        medium sales_price  signed  stamped  \
# 0  watercolor and ink / paper     45900.0     1.0      0.0
# 1  watercolor and ink / paper         0.0     1.0      0.0
# 2  watercolor and ink / paper     22950.0     1.0      0.0
# 3  watercolor and ink / paper    433330.0     1.0      0.0
# 4  watercolor and ink / paper     12240.0     1.0      0.0
#
#                                          title  width aspect_ratio    area  \
# 0                              Misty Landscape  16.93         1.99  569.86
# 1                Conversations in the Mountain  10.43         1.30  141.64
# 2  Peony and Insects / Peony and Butterfly (2)    NaN          NaN     NaN
# 3                     Retreat in the Mountains  15.55         2.63  636.62
# 4                       Villagers in the Woods  18.82         2.10  743.95
#
#    sold  sales_price_usd
# 0     1          45900.0
# 1     0              0.0
# 2     1          22950.0
# 3     1         433330.0
# 4     1          12240.0
#
# [5 rows x 26 columns]

# %%
# Now we should do the same for the low_estimate and high_estimate columns

# How many rows have null values in the estimate columns?
df['low_estimate'].isnull().sum()
df['high_estimate'].isnull().sum()
# Out:
# 2084

# %%
# Drop the rows with null values in the estimate columns
df = df.dropna(subset=['low_estimate'])
df = df.dropna(subset=['high_estimate'])

# %%
# Create empty columns for the low and high estimates in USD
df['low_estimate_usd'] = np.nan
df['high_estimate_usd'] = np.nan

# %%
# Now let's try to convert using the date of the auction

#loop through the rows and convert the low_estimate to usd using the date of the auction
for index, row in df.iterrows():
    if row['currency'] != 'USD':     #only the currency is NOT USD already
        df.loc[index, 'low_estimate_usd'] = c.convert(row['low_estimate'], row['currency'], 'USD', date=row['auction_date'])
    else:
        df.loc[index, 'low_estimate_usd'] = row['low_estimate']

#loop through the rows and convert the high_estimate to usd using the date of the auction
for index, row in df.iterrows():
    if row['currency'] != 'USD':     #only the currency is NOT USD already
        df.loc[index, 'high_estimate_usd'] = c.convert(row['high_estimate'], row['currency'], 'USD', date=row['auction_date'])
    else: 
        df.loc[index, 'high_estimate_usd'] = row['high_estimate']


#check the new column
df.head()
# Out:
#           artist auction_date auction_house auction_location auction_lot  \
# 0  Huang Binhong   2017-05-30     Christies        Hong Kong        1364
# 1  Huang Binhong   2017-05-30     Christies        Hong Kong        1365
# 2       Yun Tang   2017-05-30     Christies        Hong Kong        1366
# 3  Huang Binhong   2017-05-30     Christies        Hong Kong        1367
# 4       Yun Tang   2017-05-30     Christies        Hong Kong        1368
#
#   category country              created currency  dated  ... signed stamped  \
# 0    paper   China  1947-01-01 00:00:00      USD    0.0  ...    1.0     0.0
# 1    paper   China  1990-01-01 00:00:00      USD    0.0  ...    1.0     0.0
# 2    paper     NaN                  NaN      USD    0.0  ...    1.0     0.0
# 3    paper   China                  NaN      USD    0.0  ...    1.0     0.0
# 4    paper     NaN  1940-01-01 00:00:00      USD    0.0  ...    1.0     0.0
#
#                                          title  width  aspect_ratio    area  \
# 0                              Misty Landscape  16.93          1.99  569.86
# 1                Conversations in the Mountain  10.43          1.30  141.64
# 2  Peony and Insects / Peony and Butterfly (2)    NaN           NaN     NaN
# 3                     Retreat in the Mountains  15.55          2.63  636.62
# 4                       Villagers in the Woods  18.82          2.10  743.95
#
#   sold  sales_price_usd  low_estimate_usd  high_estimate_usd
# 0    1          45900.0           38490.0            64150.0
# 1    0              0.0           38490.0            64150.0
# 2    1          22950.0           15400.0            23090.0
# 3    1         433330.0          320750.0           449050.0
# 4    1          12240.0           10260.0            12830.0
#
# [5 rows x 28 columns]

# %%
# Export this new dataframe to a csv file to explore other stuff
df.to_csv('cleaned_data_with_usd.csv', index=False)

# %% [markdown]
# # Standardize Medium

# %%
# Let's see how many there are
df['medium'].nunique()
# Out:
# 8239

# %%
# Let's explore the medium column
df.groupby('medium').count()

# There are a lot of different mediums, are we going to try to classify them all?
# NLP? 
# Keep key words only? How many categories?
# Out:
#                                                     artist  auction_date  \
# medium
# ,gold leaf, collage and canvas / board                   1             1
# 132 drawn paper receipts of variable size pinne...       1             1
# 18-carat yellow gold with multi-colored enamel ...       1             1
# 23 carat repousse-cisele gold                            2             2
# 23 carat repoussé-ciselé gold                            1             1
# ...                                                    ...           ...
# wooden frames and cotton strings                         1             1
# wooden stool                                             1             1
# woodwith original box and wooden certificate of...       1             1
# woven canvas                                             1             1
# zinc alloys                                              1             1
#
#                                                     auction_house  \
# medium
# ,gold leaf, collage and canvas / board                          1
# 132 drawn paper receipts of variable size pinne...              1
# 18-carat yellow gold with multi-colored enamel ...              1
# 23 carat repousse-cisele gold                                   2
# 23 carat repoussé-ciselé gold                                   1
# ...                                                           ...
# wooden frames and cotton strings                                1
# wooden stool                                                    1
# woodwith original box and wooden certificate of...              1
# woven canvas                                                    1
# zinc alloys                                                     1
#
#                                                     auction_location  \
# medium
# ,gold leaf, collage and canvas / board                             1
# 132 drawn paper receipts of variable size pinne...                 1
# 18-carat yellow gold with multi-colored enamel ...                 1
# 23 carat repousse-cisele gold                                      2
# 23 carat repoussé-ciselé gold                                      1
# ...                                                              ...
# wooden frames and cotton strings                                   1
# wooden stool                                                       1
# woodwith original box and wooden certificate of...                 1
# woven canvas                                                       1
# zinc alloys                                                        1
#
#                                                     auction_lot  category  \
# medium
# ,gold leaf, collage and canvas / board                        1         1
# 132 drawn paper receipts of variable size pinne...            1         1
# 18-carat yellow gold with multi-colored enamel ...            1         1
# 23 carat repousse-cisele gold                                 2         2
# 23 carat repoussé-ciselé gold                                 1         1
# ...                                                         ...       ...
# wooden frames and cotton strings                              1         1
# wooden stool                                                  1         1
# woodwith original box and wooden certificate of...            1         1
# woven canvas                                                  1         1
# zinc alloys                                                   1         1
#
#                                                     country  created  \
# medium
# ,gold leaf, collage and canvas / board                    0        1
# 132 drawn paper receipts of variable size pinne...        0        1
# 18-carat yellow gold with multi-colored enamel ...        0        1
# 23 carat repousse-cisele gold                             0        2
# 23 carat repoussé-ciselé gold                             0        1
# ...                                                     ...      ...
# wooden frames and cotton strings                          0        1
# wooden stool                                              0        1
# woodwith original box and wooden certificate of...        1        1
# woven canvas                                              1        1
# zinc alloys                                               0        1
#
#                                                     currency  dated  ...  \
# medium                                                               ...
# ,gold leaf, collage and canvas / board                     1      1  ...
# 132 drawn paper receipts of variable size pinne...         1      0  ...
# 18-carat yellow gold with multi-colored enamel ...         1      1  ...
# 23 carat repousse-cisele gold                              2      2  ...
# 23 carat repoussé-ciselé gold                              1      1  ...
# ...                                                      ...    ...  ...
# wooden frames and cotton strings                           1      1  ...
# wooden stool                                               1      0  ...
# woodwith original box and wooden certificate of...         1      1  ...
# woven canvas                                               1      1  ...
# zinc alloys                                                1      1  ...
#
#                                                     signed  stamped  title  \
# medium
# ,gold leaf, collage and canvas / board                   1        1      1
# 132 drawn paper receipts of variable size pinne...       0        0      1
# 18-carat yellow gold with multi-colored enamel ...       1        1      1
# 23 carat repousse-cisele gold                            2        2      2
# 23 carat repoussé-ciselé gold                            1        1      1
# ...                                                    ...      ...    ...
# wooden frames and cotton strings                         1        1      1
# wooden stool                                             0        0      1
# woodwith original box and wooden certificate of...       1        1      1
# woven canvas                                             1        1      1
# zinc alloys                                              1        1      1
#
#                                                     width  aspect_ratio  area  \
# medium
# ,gold leaf, collage and canvas / board                  1             1     1
# 132 drawn paper receipts of variable size pinne...      0             0     0
# 18-carat yellow gold with multi-colored enamel ...      1             1     1
# 23 carat repousse-cisele gold                           2             2     2
# 23 carat repoussé-ciselé gold                           1             1     1
# ...                                                   ...           ...   ...
# wooden frames and cotton strings                        1             1     1
# wooden stool                                            1             1     1
# woodwith original box and wooden certificate of...      1             1     1
# woven canvas                                            1             1     1
# zinc alloys                                             1             1     1
#
#                                                     sold  sales_price_usd  \
# medium
# ,gold leaf, collage and canvas / board                 1                1
# 132 drawn paper receipts of variable size pinne...     1                1
# 18-carat yellow gold with multi-colored enamel ...     1                1
# 23 carat repousse-cisele gold                          2                2
# 23 carat repoussé-ciselé gold                          1                1
# ...                                                  ...              ...
# wooden frames and cotton strings                       1                1
# wooden stool                                           1                1
# woodwith original box and wooden certificate of...     1                1
# woven canvas                                           1                1
# zinc alloys                                            1                1
#
#                                                     low_estimate_usd  \
# medium
# ,gold leaf, collage and canvas / board                             1
# 132 drawn paper receipts of variable size pinne...                 1
# 18-carat yellow gold with multi-colored enamel ...                 1
# 23 carat repousse-cisele gold                                      2
# 23 carat repoussé-ciselé gold                                      1
# ...                                                              ...
# wooden frames and cotton strings                                   1
# wooden stool                                                       1
# woodwith original box and wooden certificate of...                 1
# woven canvas                                                       1
# zinc alloys                                                        1
#
#                                                     high_estimate_usd
# medium
# ,gold leaf, collage and canvas / board                              1
# 132 drawn paper receipts of variable size pinne...                  1
# 18-carat yellow gold with multi-colored enamel ...                  1
# 23 carat repousse-cisele gold                                       2
# 23 carat repoussé-ciselé gold                                       1
# ...                                                               ...
# wooden frames and cotton strings                                    1
# wooden stool                                                        1
# woodwith original box and wooden certificate of...                  1
# woven canvas                                                        1
# zinc alloys                                                         1
#
# [8239 rows x 27 columns]

# %%
#Okay I think you worked on category
df.groupby('category').count()
# Out:
#               artist  auction_date  auction_house  auction_location  \
# category
# installation       1             1              1                 1
# mixed media     1042          1042           1042              1042
# other             62            62             62                62
# painting       30361         30361          30361             30361
# paper          13827         13827          13827             13827
# photograph       117           117            117               117
# print           1086          1086           1086              1086
# sculpture       3767          3767           3767              3767
# unknown          915           915            915               915
#
#               auction_lot  country  created  currency  dated  edition  ...  \
# category                                                               ...
# installation            1        1        1         1      1        1  ...
# mixed media          1042      451      855      1042    973       57  ...
# other                  62       14       40        62     61       10  ...
# painting            30358    27031    17802     30361  30202       10  ...
# paper               13827    10960     7381     13827  13510        3  ...
# photograph            117      117       57       117    117        1  ...
# print                1086     1064      475      1086   1084       28  ...
# sculpture            3766     3438     1560      3767   3715      312  ...
# unknown               915      882      194       915    908        1  ...
#
#               signed  stamped  title  width  aspect_ratio   area   sold  \
# category
# installation       1        1      1      1             0      1      1
# mixed media      973      973   1042    972           971    972   1042
# other             61       61     62     53            53     53     62
# painting       30202    30202  30361  30128         30104  30128  30361
# paper          13510    13510  13827  13292         13288  13292  13827
# photograph       117      117    117    117           117    117    117
# print           1084     1084   1086   1083          1083   1083   1086
# sculpture       3715     3715   3767   3695          3682   3695   3767
# unknown          908      908    915    897           892    897    915
#
#               sales_price_usd  low_estimate_usd  high_estimate_usd
# category
# installation                1                 1                  1
# mixed media              1042              1042               1042
# other                      62                62                 62
# painting                30361             30361              30361
# paper                   13827             13827              13827
# photograph                117               117                117
# print                    1086              1086               1086
# sculpture                3767              3767               3767
# unknown                   915               915                915
#
# [9 rows x 27 columns]

# %% [markdown]
# # Country

# %%
# How many cells without country?
df[df['country'].isnull()]
# Out:
#                                   artist auction_date auction_house  \
# 2                               Yun Tang   2017-05-30     Christies
# 4                               Yun Tang   2017-05-30     Christies
# 5                              Bangda Xu   2017-05-30     Christies
# 6                               Hufan Wu   2017-05-30     Christies
# 7                          Shixuan Zheng   2017-05-30     Christies
# ...                                  ...          ...           ...
# 51040  Willem Van Tetrode (attribued To)   2014-01-30     Sothebys
# 51253            William Scrots (school)   2012-07-04     Sothebys
# 53518                          Zhou Chen   2012-11-26    Christies
# 53519                          Zhou Chen   2011-11-28    Christies
# 53520                          Zhou Chen   2013-05-27    Christies
#
#                    auction_location auction_lot   category country  \
# 2                         Hong Kong        1366      paper     NaN
# 4                         Hong Kong        1368      paper     NaN
# 5                         Hong Kong        1369      paper     NaN
# 6                         Hong Kong        1370      paper     NaN
# 7                         Hong Kong        1371      paper     NaN
# ...                             ...         ...        ...     ...
# 51040   The United States: New York         116  sculpture     NaN
# 51253        United Kingdom: London          10   painting     NaN
# 53518              China: Hong Kong         818      paper     NaN
# 53519              China: Hong Kong        1702      paper     NaN
# 53520              China: Hong Kong         741      paper     NaN
#
#                    created currency  dated  ... signed stamped  \
# 2                      NaN      USD    0.0  ...    1.0     0.0
# 4      1940-01-01 00:00:00      USD    0.0  ...    1.0     0.0
# 5                      NaN      USD    0.0  ...    1.0     0.0
# 6                      NaN      USD    0.0  ...    1.0     0.0
# 7      1951-01-01 00:00:00      USD    0.0  ...    1.0     0.0
# ...                    ...      ...    ...  ...    ...     ...
# 51040                  NaN      USD    0.0  ...    0.0     0.0
# 51253                  NaN      GBP    0.0  ...    0.0     0.0
# 53518                  NaN      HKD    0.0  ...    0.0     0.0
# 53519                  NaN      HKD    0.0  ...    0.0     0.0
# 53520                  NaN      HKD    0.0  ...    1.0     0.0
#
#                                              title   width  aspect_ratio  \
# 2      Peony and Insects / Peony and Butterfly (2)     NaN           NaN
# 4                           Villagers in the Woods   18.82          2.10
# 5                                  Scholar Boating   16.93          2.02
# 6                                 Autumn Landscape   26.50          0.81
# 7                                Four Beauties (4)     NaN           NaN
# ...                                            ...     ...           ...
# 51040                SAMSON SLAYING THE PHILISTINE    0.00           inf
# 51253            PORTRAIT OF EDWARD VI (1537-1553)   27.95          1.32
# 53518                      Fishing in a Quiet Lake   21.65          0.33
# 53519                       Pavilions by the River   18.74          0.35
# 53520                                River Scenery  804.33          0.02
#
#            area sold  sales_price_usd  low_estimate_usd  high_estimate_usd
# 2           NaN    1     2.295000e+04      1.540000e+04       2.309000e+04
# 4        743.95    1     1.224000e+04      1.026000e+04       1.283000e+04
# 5        579.85    1     1.836000e+04      6.420000e+03       8.980000e+03
# 6        568.69    0     0.000000e+00      3.849000e+04       6.415000e+04
# 7           NaN    1     9.487000e+04      1.026000e+04       1.540000e+04
# ...         ...  ...              ...               ...                ...
# 51040      0.00    1     3.301000e+06      8.000000e+05       1.200000e+06
# 51253   1034.43    1     2.779166e+06      7.818725e+05       1.094622e+06
# 53518    155.88    1     1.109666e+05      3.870929e+04       5.161239e+04
# 53519    123.87    1     1.565251e+05      2.565986e+04       3.848978e+04
# 53520  13617.31    1     6.619366e+06      1.030452e+06       1.288065e+06
#
# [7226 rows x 28 columns]

# %%
# So, 12920 rows without country, how many artists?
df[df['country'].isnull()].groupby('artist').size().sort_values(ascending=False).head(20)

# 1928 artists, hopefully only a few of them make up most of the rows
# Out:
# artist
# Keran Li              38
# Zhen Wang             37
# Chunya Zhou           37
# Tay Bak Koi           36
# Shanshen Yang         33
# Atsuko Tanaka         33
# Henri Mege            32
# Pang Jiun             32
# Shifa Cheng           30
# Xiaogang Zhang        30
# Youren Yu             30
# Cui Ruzhuo            30
# Shiryu Morita         29
# On Kawara             29
# Dayu Wu               28
# Dan Liu               28
# Zikai Feng            28
# AY T Joe Christine    27
# Dan Colen             27
# Sanghwa Chung         27
# dtype: int64
